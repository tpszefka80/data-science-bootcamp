# %% [markdown]
# <a href="https://colab.research.google.com/github/tpszefka80/data-science-bootcamp/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Halo Colab')
# Out:
# Halo Colab
